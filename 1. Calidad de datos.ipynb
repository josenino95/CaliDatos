# %%
# Leer librerias necesarias
import pandas as pd
import numpy as np

# %%
# Importar script que ejecuta en lote (batch) el script de calidad
from batch_calidad_datos import batch_calidad_datos

# %%
batch_calidad_datos(
    corte='06_07_2023', nombre_log_datos='log.xlsx',
    archivo_datos=r'datos/datos_prueba_1.xlsx',
    hoja_datos='Datos',
    inicial_fila=1,
    archivo_datos_dic=r'datos/diccionario_prueba_1.xlsx',
    hoja_datos_dic='Diccionario',
    inicial_fila_dic=12
  )
# Out:
# Se creo archivo log log.xlsx
# Se leyó el conjunto de datos.
#  No hay columnas con nombres repetidos.
#  Se agregó al archivo de resultados la hoja 1.SugerenciaNombresVariables con las sugerencias de nombres de las variables
# Se actualizó el archivo log log.xlsx
# 100%|██████████| 14/14 [00:00<00:00, 204.35it/s]
# Se actualizó el archivo log log.xlsx
# Se actualizó el archivo log log.xlsx
# Se actualizó el archivo log log.xlsx
# 100%|██████████| 13/13 [00:00<00:00, 222.38it/s]
# Se actualizó el archivo log log.xlsx
# 100%|██████████| 13/13 [00:00<00:00, 213.90it/s]
# Se actualizó el archivo log log.xlsx
# 100%|██████████| 13/13 [00:00<00:00, 108.71it/s]
# Se actualizó el archivo log log.xlsx
# Se actualizó el archivo log log.xlsx
